# %%
# Collect Elevation Code

import requests

#Google Elevation API Key
key = 'xxx' #Enter API key here

# url for Google Elevation API
base_url = 'https://maps.googleapis.com/maps/api/elevation/json?'

# function that returns the elevation in meters above sea-level of a set of given lat/lng coordinates
# takes inputes (latitude, longitude, API key)

def get_elevation(lat,lng,key):
    call = requests.get(base_url + 'locations='+str(lat)+','+str(lng)+'&key='+key)
    result = call.json()
    return result['results'][0]['elevation']

### Example ###
# 39.7555° N, 105.2211° W
#get_elevation(39.7555,-105.2211,key)
# Notice the longitude coordinate for W is negative!

# %%
# read in new data
import pandas as pd

data = pd.read_csv('../data/places_nearby_results_denver_co_20200213.csv')

# %%
data.shape
# Out:
# (946, 7)

# %%
data['types']
# Out:
# 0      ['airport', 'point_of_interest', 'establishment']
# 1      ['airport', 'point_of_interest', 'establishment']
# 2      ['airport', 'point_of_interest', 'establishment']
# 3      ['airport', 'point_of_interest', 'establishment']
# 4      ['hospital', 'airport', 'point_of_interest', '...
#                              ...
# 941    ['veterinary_care', 'point_of_interest', 'esta...
# 942    ['veterinary_care', 'point_of_interest', 'esta...
# 943    ['veterinary_care', 'health', 'point_of_intere...
# 944    ['veterinary_care', 'point_of_interest', 'esta...
# 945    ['veterinary_care', 'point_of_interest', 'esta...
# Name: types, Length: 946, dtype: object

# %%
data[35:65]
# Out:
#                                              geometry  \
# 35  {'location': {'lat': 39.7218547, 'lng': -105.1...
# 36  {'location': {'lat': 39.72435, 'lng': -105.133...
# 37  {'location': {'lat': 39.745185, 'lng': -104.98...
# 38  {'location': {'lat': 39.7463779, 'lng': -104.9...
# 39  {'location': {'lat': 39.743635, 'lng': -104.98...
# 40  {'location': {'lat': 39.743489, 'lng': -104.97...
# 41  {'location': {'lat': 39.7366306, 'lng': -104.9...
# 42  {'location': {'lat': 39.74296089999999, 'lng':...
# 43  {'location': {'lat': 39.8031283, 'lng': -104.9...
# 44  {'location': {'lat': 39.7459557, 'lng': -104.9...
# 45  {'location': {'lat': 39.7481242, 'lng': -104.9...
# 46  {'location': {'lat': 39.82421069999999, 'lng':...
# 47  {'location': {'lat': 39.7080993, 'lng': -104.8...
# 48  {'location': {'lat': 39.6804778, 'lng': -104.9...
# 49  {'location': {'lat': 39.7462956, 'lng': -104.9...
# 50  {'location': {'lat': 39.65223749999999, 'lng':...
# 51  {'location': {'lat': 39.77030139999999, 'lng':...
# 52  {'location': {'lat': 39.72072319999999, 'lng':...
# 53  {'location': {'lat': 39.710505, 'lng': -105.01...
# 54  {'location': {'lat': 39.65415340000001, 'lng':...
# 55  {'location': {'lat': 39.7497862, 'lng': -104.9...
# 56  {'location': {'lat': 39.7970106, 'lng': -105.0...
# 57  {'location': {'lat': 39.784925, 'lng': -105.02...
# 58  {'location': {'lat': 39.7967328, 'lng': -105.0...
# 59  {'location': {'lat': 39.73983010000001, 'lng':...
# 60  {'location': {'lat': 39.74917900000001, 'lng':...
# 61  {'location': {'lat': 39.7441456, 'lng': -104.9...
# 62  {'location': {'lat': 39.75334590000001, 'lng':...
# 63  {'location': {'lat': 39.71737629999999, 'lng':...
# 64  {'location': {'lat': 39.7204208, 'lng': -104.9...
#
#                                        name  \
# 35                    Westerra Credit Union
# 36                    Safehold Special Risk
# 37                                      ATM
# 38                                      ATM
# 39                                FirstBank
# 40                        Watercourse Foods
# 41                             City O' City
# 42                       Marczyk Fine Foods
# 43                               Kellogg Co
# 44                             D Bar Denver
# 45             The Market at Larimer Square
# 46                       Etai's Bakery Cafe
# 47                            Auntie Anne's
# 48              Perkins Restaurant & Bakery
# 49  Mermaids Bakery- Cupcakes, Cakes & Pies
# 50                           Walmart Bakery
# 51                           Walmart Bakery
# 52                           Sugar Bakeshop
# 53       Pacific Ocean Marketplace - Denver
# 54              The Bagel Deli & Restaurant
# 55                Cake Crumbs Bakery & Cafe
# 56                    Einstein Bros. Bagels
# 57                              Village Inn
# 58                      Cold Stone Creamery
# 59                             Panera Bread
# 60                                FirstBank
# 61                         Wells Fargo Bank
# 62                 First Western Trust Bank
# 63                    Colorado Capital Bank
# 64              Community Banks of Colorado
#
#                                             plus_code  \
# 35  {'compound_code': 'PVC8+PW Lakewood, Colorado,...
# 36  {'compound_code': 'PVF8+PP Lakewood, Colorado,...
# 37  {'compound_code': 'P2W6+35 Denver, Colorado, U...
# 38  {'compound_code': 'P2W6+HH Denver, Colorado, U...
# 39  {'compound_code': 'P2V6+FJ Denver, Colorado, U...
# 40  {'compound_code': 'P2VF+9C Denver, Colorado, U...
# 41  {'compound_code': 'P2P8+M5 Denver, Colorado, U...
# 42  {'compound_code': 'P2VC+5Q Denver, Colorado, U...
# 43  {'compound_code': 'R239+78 North Washington, C...
# 44  {'compound_code': 'P2W9+9F Denver, Colorado, U...
# 45  {'compound_code': 'P2X2+68 Denver, Colorado, U...
# 46  {'compound_code': 'R2F8+M8 Denver, Colorado, U...
# 47  {'compound_code': 'P55G+6M Aurora, Colorado, U...
# 48  {'compound_code': 'M3J5+58 Denver, Colorado, U...
# 49  {'compound_code': 'P2W4+G5 Denver, Colorado, U...
# 50  {'compound_code': 'M42C+V9 Denver, Colorado, U...
# 51  {'compound_code': 'Q4C3+47 Denver, Colorado, U...
# 52  {'compound_code': 'P2C6+7V Denver, Colorado, U...
# 53  {'compound_code': 'PX6P+6H Denver, Colorado, U...
# 54  {'compound_code': 'M33P+MC Denver, Colorado, U...
# 55  {'compound_code': 'P3XM+W3 Denver, Colorado, U...
# 56  {'compound_code': 'QWWC+RG Arvada, Colorado, U...
# 57  {'compound_code': 'QXMG+X4 Denver, Colorado, U...
# 58  {'compound_code': 'QWWC+MP Arvada, Colorado, U...
# 59  {'compound_code': 'P5Q7+WQ Aurora, Colorado, U...
# 60  {'compound_code': 'P2X3+MH Denver, Colorado, U...
# 61  {'compound_code': 'P2V7+M8 Denver, Colorado, U...
# 62  {'compound_code': 'QX3W+8M Denver, Colorado, U...
# 63  {'compound_code': 'P383+X9 Denver, Colorado, U...
# 64  {'compound_code': 'P2C6+5Q Denver, Colorado, U...
#
#                                                 types  \
# 35  ['atm', 'finance', 'point_of_interest', 'estab...
# 36  ['insurance_agency', 'atm', 'finance', 'point_...
# 37  ['atm', 'finance', 'point_of_interest', 'estab...
# 38  ['atm', 'finance', 'point_of_interest', 'estab...
# 39  ['bank', 'atm', 'finance', 'point_of_interest'...
# 40  ['bakery', 'restaurant', 'food', 'point_of_int...
# 41  ['bakery', 'cafe', 'bar', 'restaurant', 'food'...
# 42  ['bakery', 'grocery_or_supermarket', 'food', '...
# 43  ['bakery', 'food', 'point_of_interest', 'store...
# 44  ['bakery', 'cafe', 'bar', 'restaurant', 'food'...
# 45  ['bakery', 'restaurant', 'food', 'point_of_int...
# 46  ['cafe', 'bakery', 'restaurant', 'food', 'poin...
# 47  ['restaurant', 'bakery', 'cafe', 'food', 'poin...
# 48  ['restaurant', 'bakery', 'food', 'point_of_int...
# 49  ['bakery', 'food', 'point_of_interest', 'store...
# 50  ['bakery', 'food', 'point_of_interest', 'store...
# 51  ['bakery', 'food', 'point_of_interest', 'store...
# 52  ['bakery', 'cafe', 'food', 'point_of_interest'...
# 53  ['bakery', 'supermarket', 'grocery_or_supermar...
# 54  ['restaurant', 'bakery', 'meal_takeaway', 'foo...
# 55  ['bakery', 'cafe', 'restaurant', 'food', 'poin...
# 56  ['bakery', 'cafe', 'restaurant', 'food', 'poin...
# 57  ['bakery', 'restaurant', 'food', 'point_of_int...
# 58  ['bakery', 'food', 'point_of_interest', 'store...
# 59  ['bakery', 'meal_takeaway', 'cafe', 'restauran...
# 60  ['bank', 'atm', 'finance', 'point_of_interest'...
# 61  ['bank', 'atm', 'finance', 'point_of_interest'...
# 62  ['bank', 'atm', 'finance', 'point_of_interest'...
# 63  ['bank', 'finance', 'point_of_interest', 'esta...
# 64  ['bank', 'atm', 'finance', 'point_of_interest'...
#
#                                            vicinity   latitude   longitude
# 35                    375 Union Boulevard, Lakewood  39.721855 -105.132743
# 36               575 Union Boulevard #205, Lakewood  39.724350 -105.133161
# 37                          555 17th Street, Denver  39.745185 -104.989549
# 38                       1750 Welton Street, Denver  39.746378 -104.988597
# 39                          370 17th Street, Denver  39.743635 -104.988499
# 40                     837 East 17th Avenue, Denver  39.743489 -104.976399
# 41                     206 East 13th Avenue, Denver  39.736631 -104.984542
# 42               770 East 17th Avenue #1405, Denver  39.742961 -104.978087
# 43              451 East 58th Avenue # 1370, Denver  39.803128 -104.981720
# 44                     494 East 19th Avenue, Denver  39.745956 -104.981358
# 45                      1445 Larimer Street, Denver  39.748124 -104.999214
# 46                     101 East 70th Avenue, Denver  39.824211 -104.984197
# 47  14200 East Alameda Avenue Space 2049- A, Aurora  39.708099 -104.823289
# 48            1995 South Colorado Boulevard, Denver  39.680478 -104.941648
# 49                       1543 Champa Street, Denver  39.746296 -104.994604
# 50                 9400 East Hampden Avenue, Denver  39.652237 -104.879117
# 51                          7800 Smith Road, Denver  39.770301 -104.896807
# 52                             277 Broadway, Denver  39.720723 -104.987854
# 53             2200 West Alameda Avenue #2B, Denver  39.710505 -105.013596
# 54                 6439 East Hampden Avenue, Denver  39.654153 -104.913986
# 55                      2216 Kearney Street, Denver  39.749786 -104.917311
# 56             5545 Wadsworth Bypass unit b, Arvada  39.797011 -105.078646
# 57                   4850 Federal Boulevard, Denver  39.784925 -105.024743
# 58              5545 Wadsworth Bypass ste d, Arvada  39.796733 -105.078220
# 59                 13100 East Colfax Avenue, Aurora  39.739830 -104.835621
# 60                    1200 17th Street #100, Denver  39.749179 -104.996001
# 61                            1740 Broadway, Denver  39.744146 -104.986682
# 62              1900 16th Street Mall #1200, Denver  39.753346 -105.003283
# 63                        55 Madison Street, Denver  39.717376 -104.946539
# 64            277 Broadway Suite C, Suite C, Denver  39.720421 -104.988069
